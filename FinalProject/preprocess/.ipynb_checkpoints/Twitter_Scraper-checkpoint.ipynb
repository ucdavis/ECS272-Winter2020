# %%
import tweepy
import got3
from twitterscraper import query_tweets
import datetime

import json

# %% [markdown]
# ## TwitterScraper

# %%
tweets_scr = query_tweets("#coronavirus", 
                              begindate=datetime.date(2020,1,1), 
                              #enddate=datetime.date(2020,1,31),
                              limit=10000,
                              lang='en', 
                              poolsize=20)
# Out:
# INFO: queries: ['#coronavirus since:2020-01-01 until:2020-01-02', '#coronavirus since:2020-01-02 until:2020-01-04', '#coronavirus since:2020-01-04 until:2020-01-05', '#coronavirus since:2020-01-05 until:2020-01-07', '#coronavirus since:2020-01-07 until:2020-01-08', '#coronavirus since:2020-01-08 until:2020-01-10', '#coronavirus since:2020-01-10 until:2020-01-11', '#coronavirus since:2020-01-11 until:2020-01-13', '#coronavirus since:2020-01-13 until:2020-01-14', '#coronavirus since:2020-01-14 until:2020-01-16', '#coronavirus since:2020-01-16 until:2020-01-17', '#coronavirus since:2020-01-17 until:2020-01-19', '#coronavirus since:2020-01-19 until:2020-01-20', '#coronavirus since:2020-01-20 until:2020-01-22', '#coronavirus since:2020-01-22 until:2020-01-23', '#coronavirus since:2020-01-23 until:2020-01-25', '#coronavirus since:2020-01-25 until:2020-01-26', '#coronavirus since:2020-01-26 until:2020-01-28', '#coronavirus since:2020-01-28 until:2020-01-29', '#coronavirus since:2020-01-29 u
# ...

# %%
print(len(tweets_scr))
# Out:
# 8479

# %%
tweets_scr = sorted(list_of_tweets, key=lambda x: x.timestamp)

for tweet in tweets_scr:
    if tweet.likes > 100:
        print('Retweets', tweet.retweets, 'on', tweet.timestamp)
        print(tweet.text)
        print()
        print()
# Out:
# Retweets 83 on 2020-01-09 01:29:08
# According to @CCTV report,
#
# 1. A complete genome of a novel #coronavirus has been obtained.
#
# 2. 15 positives have been detected based on such genome in molecular diagnostics.
#
# 3. Viral isolation has been done on 1 sample which shows the morphology of coronavirus under EM.
#
#
# Retweets 183 on 2020-01-09 07:04:28
# Chinese authorities have made a preliminary determination of the cause of #pneumonia in Wuhan as a novel (new) #coronavirus. @WHO continues to monitor the situation closely and is ready to support #China to investigate and respond to this outbreak.  https://www.who.int/china/news/detail/09-01-2020-who-statement-regarding-cluster-of-pneumonia-cases-in-wuhan-china … (1/7)
#
#
# Retweets 105 on 2020-01-09 14:10:01
# ...

# %%
output = []

for tweet in tweets_scr:
    output.append({
        'username': tweet.username,
        'user_id': tweet.user_id,
        'tweet_id': tweet.tweet_id,
        'tweet_url': tweet.tweet_url,
        'timestamp': int(tweet.timestamp.timestamp()),
        'text': tweet.text,
        'likes': tweet.likes,
        'retweets': tweet.retweets,
        'replies': tweet.replies,
    })
    
output = {
    'tweets': output
}

# %%
with open('twitter.json', 'w') as out_file:
    json.dump(output, out_file)

# %% [markdown]
# ## GoT3

# %%
criteria = got3.manager.TweetCriteria().setSince('2020-02-28').setUntil('2020-02-29').setMaxTweets(1000).setQuerySearch('#coronavirus').setLang('English').setTopTweets(True)
tweets_got = got3.manager.TweetManager.getTweets(criteria)

# %%
print(len(tweets))
# Out:
# 1000

# %%
for tweet in tweets:
    print(tweet.date)
# Out:
# 2020-02-28 15:59:59
# 2020-02-28 15:59:59
# 2020-02-28 15:59:57
# 2020-02-28 15:59:56
# 2020-02-28 15:59:55
# 2020-02-28 15:59:55
# 2020-02-28 15:59:55
# 2020-02-28 15:59:53
# 2020-02-28 15:59:52
# 2020-02-28 15:59:51
# 2020-02-28 15:59:50
# 2020-02-28 15:59:49
# 2020-02-28 15:59:48
# 2020-02-28 15:59:47
# 2020-02-28 15:59:46
# 2020-02-28 15:59:46
# 2020-02-28 15:59:45
# 2020-02-28 15:59:44
# 2020-02-28 15:59:44
# 2020-02-28 15:59:42
# 2020-02-28 15:59:40
# 2020-02-28 15:59:39
# 2020-02-28 15:59:39
# 2020-02-28 15:59:39
# 2020-02-28 15:59:38
# 2020-02-28 15:59:36
# 2020-02-28 15:59:35
# 2020-02-28 15:59:33
# 2020-02-28 15:59:32
# 2020-02-28 15:59:31
# 2020-02-28 15:59:29
# 2020-02-28 15:59:25
# 2020-02-28 15:59:23
# 2020-02-28 15:59:19
# 2020-02-28 15:59:19
# 2020-02-28 15:59:16
# 2020-02-28 15:59:15
# 2020-02-28 15:59:15
# 2020-02-28 15:59:14
# 2020-02-28 15:59:14
# 2020-02-28 15:59:14
# 2020-02-28 15:59:14
# 2020-02-28 15:59:12
# 2020-02-28 15:59:12
# 2020-02-28 15:59:12
# ...

# %% [markdown]
# ## Official

# %%
access_token = ''
access_token_secret = ''

consumer_key = ''
consumer_secret = ''

# %%
import tweepy

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
for trends in api.trends_place(1):
    for trend in trends["trends"]:
        print(trend["name"])

# %%
for result in api.search('#coronavirus #virus', count=2000, lang='en', until='2020-02-22'):
    print(result._json['created_at'],result._json['text'])
